# %% [markdown]
# # Python Programming Exercises
# ---
# **Instructions:**
# Read the docstring inside each function or class and write your implementation below it. Remove the `pass` or default `return` statements and replace them with your working code.

# %%
import math
import random

# %% [markdown]
# ## Control Flow

# %%
def sum_1_to_50():
    """Use a for loop to sum the values from 1 to 50 and print the result."""
    sum = 0
    for i in range(51):
      sum += i
    print(sum)

def check_prime_loop(n):
    """Use a for loop to check if a positive number is prime or not and print the result."""
    if n == 1:
      print("1 is not prime")
      return
    for i in range(2,n):
      if n % i == 0:
        print(f"{n} is not prime")
        return
    print(f"{n} IS prime")



def compute_factorial_loop(n):
    """Use a for loop to compute the factorial of a number and print the result."""
    pass

def sum_5_to_50():
    """Use a for loop to sum all the values from 5 to 50 and print the result."""
    pass




def sum_even_range():
    """Use a for loop to sum all the even numbers from 5 to 50, using range and print the result."""
    sum = 0
    for i in range(6,51,2):
      sum += i
    print(f"the sum is {sum}")




def sum_even_if():
    """Use a for loop to sum all the even numbers from 5 to 50, using an if statement and print the result."""
    sum_even = 0
    sum_odd = 0
    for num in range(5,51):
      if num % 2 == 0:
        sum_even += num
      else:
        sum_odd += num
    print(f"this sum is also {sum_even}")
    print(f"the odd sum is  {sum_odd}")


print("the output is")
sum_1_to_50()

sum_even_range()
sum_even_if()


# for i in range(1,51):
#   check_prime_loop(i)
# Out:
# the output is
# 1275
# the sum is 644
# this sum is also 644
# the odd sum is  621

# %% [markdown]
# ## Functions

# %%
def is_prime(x):
    """Accepts one parameter, x, and returns True if x is prime and False otherwise."""
    return False

def factorial(x):
    """Accepts one parameter, x, and returns x! (x factorial)."""
    result = 1
    for i in range(1,x+1):
      result *= i
    return result

def binomial_coefficient(n, k):
    """Accepts two parameters, n and k, and computes the binomial coefficient formula: n! / (k!(n-k)!)."""
    # lemala = factorial(n)
    # lemata1 = factorial(k)
    # lemata2 = factorial(n-k)
    # result = lemala / (lemata1 * lemata2)
    # return result
    return factorial(n) / (factorial(k)*factorial(n-k))

def print_fibonacci(n):
    """Accepts one parameter, n, and prints the first n elements in the Fibonacci series."""
    pass

y = 7
print(f"the factorial of {y} is {factorial(y)}")

n = 6
k = 3
print(f"{n} choose {k} = {binomial_coefficient(n,k)}")
# Out:
# the factorial of 7 is 5040
# 6 choose 3 = 20.0

# %% [markdown]
# ## Containers: Lists

# %%
x = 5
print(isinstance(x, int))
# Out:
# True

# %%
lst = [1,20,3]
lst1 = [1, "bla", 3.5]

def func1(l):
  for item in l:
    if not isinstance(item, int):
      return None

  max = l[0]
  for item in l:
    if item > max:
      max = item
  return max

print(func1(lst))
print(func1(lst1))
# Out:
# 20
# None

# %%
def is_purely_integers(lst):
    """Returns True if the list contains only integers and False otherwise (using isinstance)."""
    return False

def max_pure_integers(lst):
    """Returns None if the list is not purely integers, otherwise returns the maximum value."""
    return None

def symmetric_difference(l1, l2):
    """Returns a list containing only elements which are either in l1 or in l2 but not both."""
    return []

def remove_list_duplications(lst):
    """Returns a new list without any duplications."""
    newlst = []
    for item in lst:
      # look for item in the new list
      foundItem = "No"
      for item1 in newlst:
        if item == item1:
          foundItem = "Yes"

      # I didnt item in the new list so I add to the new list
      if foundItem == "No":
        newlst.append(item)
    return newlst




def list_intersection(l1, l2):
    """Returns a new list containing the intersection of both lists."""
    return []

def list_union(l1, l2):
    """Returns a new list containing the union of both lists without duplications."""
    newlst = []
    for item in l1:
      newlst.append(item)
    for item in l2:
      newlst.append(item)
    return remove_list_duplications(newlst)

def custom_sort(lst):
    """Returns the list sorted from low to high without using the built-in sort function."""
    return []

# %%
l1 = [1,2,3]
l2 = [2,3,5,6]
l3 = list_union(l1, l2) # [1,2,3,5,6]
print(l3)

l4 = [1,2,3,4,2,1]
l5 = remove_list_duplications(l4)
print(l5)
# Out:
# [1, 2, 3, 5, 6]
# [1, 2, 3, 4]

# %% [markdown]
# ## Containers: Tuples

# %%
def check_tuple_id(tup, id_to_check):
    """
    Assuming a tuple has the structure (ID, Name, Phone number).
    Returns False if the IDs don’t match, and returns the Phone number if they do.
    """
    pass

def get_phone_numbers(tuple_list, id_list):
    """When given a list of tuples and a list of IDs, returns a list of phone numbers for the given IDs."""
    return []

# %% [markdown]
# ## Containers: Dictionaries

# %%
dict = {"name":"Leon", "age": 42, "Address":"Haifa"} #KVP - Key Value Pair
print(dict['age'])
# print(dict['salary']) # Error
# Out:
# 42

# %%
def lists_to_dict(l1, l2):
    """When given two lists of equal length, returns a dictionary where l1 is keys and l2 is values."""
    dict = {}
    # for index in range(len(l1)):
    #   key = l1[index]
    #   value = l2[index]
    #   dict[key] = value
    for k,v in zip(l1,l2):
      dict[k] = v
    return dict


def word_count(sentence):
    """
    Returns a dictionary showcasing the count of each word in the sentence.
    Figure out how to convert your sentence to a list of words in one line.
    """
    return {}

# %%
l1 = ["Name", "Age", "Address"]
l2 = ["Leon", 42, "Haifa"]
dict = lists_to_dict(l1,l2)
print(dict)
# Out:
# {'Name': 'Leon', 'Age': 42, 'Address': 'Haifa'}

# %% [markdown]
# ## Containers: Sets

# %%
s1 = set([1,2,1,3,2,5])
print(s1)
s2 = {1,2,3,4,1,2,3}
print(s2)

print(s1.union(s2))
print(s1.intersection(s2))
print(s1.difference(s2))
print(s2.difference(s1))
print(s1.symmetric_difference(s2))
# Out:
# {1, 2, 3, 5}
# {1, 2, 3, 4}
# {1, 2, 3, 4, 5}
# {1, 2, 3}
# {5}
# {4}
# {4, 5}

# %%
def remove_duplications_with_set(lst):
    """Returns a new list without any duplications (it is okay to change the elements' order)."""
    s1 = set(lst)
    return list(s1)

def set_intersection_ignore_duplications(l1, l2):
    """Returns a new list containing the intersection of both lists while ignoring duplications."""
    return []

def list_in_set(s, lst):
    """Returns True if all the list elements are in the set, and False otherwise."""
    return False

# %%
l = [1,2,3,1,1,2,3,4]
print(remove_duplications_with_set(l))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## Test Your Code
# You can use the cell below to test your functions as you write them.

# %%
# Example: print(is_prime(7))
